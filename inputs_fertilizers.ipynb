# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
npk= pd.read_csv('F:\PANDAS.csv')
npk
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Lala Gallery\Desktop\PANDAS\inputs_fertilizers.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Lala%20Gallery/Desktop/PANDAS/inputs_fertilizers.ipynb#ch0000001?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lala%20Gallery/Desktop/PANDAS/inputs_fertilizers.ipynb#ch0000001?line=1'>2</a> npk= pd.read_csv('F:\PANDAS.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/Lala%20Gallery/Desktop/PANDAS/inputs_fertilizers.ipynb#ch0000001?line=2'>3</a> npk
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
import pandas as pd
npk = pd.read_csv('FAOSTAT_data_4-16-2022.csv')
npk.head()
# Out:
#   Domain Code                   Domain  Area Code (FAO)      Area  \
# 0         RFN  Fertilizers by Nutrient              131  Malaysia
# 1         RFN  Fertilizers by Nutrient              131  Malaysia
# 2         RFN  Fertilizers by Nutrient              131  Malaysia
# 3         RFN  Fertilizers by Nutrient              131  Malaysia
# 4         RFN  Fertilizers by Nutrient              131  Malaysia
#
#    Element Code           Element  Item Code                         Item  \
# 0          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 1          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 2          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 3          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
# 4          5157  Agricultural Use       3102  Nutrient nitrogen N (total)
#
#    Year Code  Year    Unit      Value Flag            Flag Description
# ...

# %%
npk.describe
# Out:
# <bound method NDFrame.describe of    Domain Code                   Domain  Area Code (FAO)      Area  \
# 0          RFN  Fertilizers by Nutrient              131  Malaysia
# 1          RFN  Fertilizers by Nutrient              131  Malaysia
# 2          RFN  Fertilizers by Nutrient              131  Malaysia
# 3          RFN  Fertilizers by Nutrient              131  Malaysia
# 4          RFN  Fertilizers by Nutrient              131  Malaysia
# 5          RFN  Fertilizers by Nutrient              131  Malaysia
# 6          RFN  Fertilizers by Nutrient              131  Malaysia
# 7          RFN  Fertilizers by Nutrient              131  Malaysia
# 8          RFN  Fertilizers by Nutrient              131  Malaysia
# 9          RFN  Fertilizers by Nutrient              131  Malaysia
# 10         RFN  Fertilizers by Nutrient              131  Malaysia
# 11         RFN  Fertilizers by Nutrient              131  Malaysia
# ...

# %%
import csv
file = open("FAOSTAT_data_4-16-2022.csv")
csvreader = csv.reader(file)
header = next(csvreader)
print(header)
rows = []
for row in csvreader:
    rows.append(row)
print(rows)
file.close()

# %%
npk.mean()
# Out:
# C:\Users\Lala Gallery\AppData\Local\Temp\ipykernel_15032\2928703399.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   npk.mean()
# Area Code (FAO)    1.480000e+02
# Element Code       5.157000e+03
# Item Code          3.103000e+03
# Year Code          2.017000e+03
# Year               2.017000e+03
# Value              1.030869e+06
# dtype: float64

# %%
a=npk.value_counts(["Value"]).mean()
a
# Out:
# 1.25

# %%
npk.groupby(["Area"]).mean()
# Out:
#           Area Code (FAO)  Element Code  Item Code  Year Code    Year  \
# Area
# Malaysia            131.0        5157.0     3103.0     2017.0  2017.0
# Pakistan            165.0        5157.0     3103.0     2017.0  2017.0
#
#                  Value
# Area
# Malaysia  5.397919e+05
# Pakistan  1.521947e+06

# %%
npk.groupby(["Area","Domain"]).mean()
# Out:
#                                   Area Code (FAO)  Element Code  Item Code  \
# Area     Domain
# Malaysia Fertilizers by Nutrient            131.0        5157.0     3103.0
# Pakistan Fertilizers by Nutrient            165.0        5157.0     3103.0
#
#                                   Year Code    Year         Value
# Area     Domain
# Malaysia Fertilizers by Nutrient     2017.0  2017.0  5.397919e+05
# Pakistan Fertilizers by Nutrient     2017.0  2017.0  1.521947e+06

# %%
npk[npk ["Value"]<476916.92].groupby(["Area","Domain"]).mean()
# Out:
#                                   Area Code (FAO)  Element Code    Item Code  \
# Area     Domain
# Malaysia Fertilizers by Nutrient            131.0        5157.0  3102.714286
# Pakistan Fertilizers by Nutrient            165.0        5157.0  3104.000000
#
#                                     Year Code         Year          Value
# Area     Domain
# Malaysia Fertilizers by Nutrient  2017.428571  2017.428571  233910.538571
# Pakistan Fertilizers by Nutrient  2017.000000  2017.000000   41970.200000

# %%
import seaborn as sns
import pandas as pd
sns.set_theme(style="darkgrid")
npk = pd.read_csv('FAOSTAT_data_4-16-2022.csv')

# Plot the responses for different events and regions
sns.lineplot(x="Value", y="Year",
             hue="Area", style="Flag",
             data=npk)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Year'>
